# %% [markdown]
# ### Creating Conda Envirnment with all dependencies for tflite

# %% [markdown]
# ### installing dependencies and creating separate conda envirnment

# %%
#!conda env create -f conda-cpu.yml
#!conda activate yolov4-cpu

# %% [markdown]
# ### generating tensorflow model from darknet framework

# %%
#!python save_model.py --output ./checkpoints/yolov4-tiny-416 --input_size 416 --model yolov4 --framework tflite --tiny

# %% [markdown]
# ### generating tflite model

# %%
#!python convert_tflite.py --weights ./checkpoints/yolov4-tiny-416 --output ./checkpoints/yolov4-tiny-416.tflite

# %% [markdown]
# ### Qunatize to float 16

# %%
#!python convert_tflite.py --weights ./checkpoints/ yolov4-tiny-416 --output ./checkpoints/yolov4-416-fp16.tflite --quantize_mode float16

# %% [markdown]
# ### Checking the Tensorflow Model

# %%
#!python detect.py --weights ./checkpoints/yolov4-tiny-416.tflite --size 416 --model yolov4 -images ./data/images/126.jpg --output ./output/output_2.jpg --framework tflite

# %%
# !pip install opencv
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv

# %%
def imShow(path):
    import cv2
    import matplotlib.pyplot as plt
    # %matplotlib inline

    image = cv2.imread(path)
    height, width = image.shape[:2]
    resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

    fig = plt.gcf()
    fig.set_size_inches(18, 10)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
imShow('detections/detection1.png')

# %% [markdown]
# ### References
# Dataset https://www.kaggle.com/datasets/thepbordin/indoor-object-detection <br>
# https://github.com/hunglc007/tensorflow-yolov4-tflite
